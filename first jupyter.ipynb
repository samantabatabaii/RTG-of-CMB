# %%
x = 4
y = 6
println(x + y)
# Out:
# 10

# %% [markdown]
# This is just a test!

# %%
using PyPlot

n = 50
srand(1)
x = rand(n)
y = 2x
plot(x, y)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x320501510>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x320f4fc50>
